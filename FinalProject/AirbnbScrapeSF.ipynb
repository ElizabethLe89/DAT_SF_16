# %%
import mechanize
import cookielib
from lxml import html
import csv
import cStringIO
import codecs
from random import randint
from time import sleep
from lxml.etree import tostring
import bs4

# %%
# Browser
br = mechanize.Browser()

# %%
# Allow cookies
cj = cookielib.LWPCookieJar()
br.set_cookiejar(cj)

# Browser options
br.set_handle_equiv(True)
br.set_handle_gzip(True)
br.set_handle_redirect(True)
br.set_handle_referer(True)
br.set_handle_robots(False)
# Out:
# /Users/lisale/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: UserWarning: gzip transfer encoding is experimental!

# %%
# Follows refresh 0 but not hangs on refresh > 0
br.set_handle_refresh(mechanize._http.HTTPRefreshProcessor(), max_time=1)
#specify browser to emulate
br.addheaders = [('User-agent', 
'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1')]

# %%
def IterateMainPage(location_string, loop_limit): 
    MainResults = []
    """
    input: 
        location_string (string) - this is a location string that conforms to the 
                                   pattern on airbnb for example, 
                                   Cambridge, MA is "Cambridge--MA"
        loop_limit (integer) -    this is the maximum number of pages you want to parse.
        
    output:
        list of dictionaries, with each list element corresponding to a unique listing
        
    This function iterates through the main listing pages where different properties
    are listed and there is a map, and collects the list of properties available along
    with the limited amount of information that is available in that page.  This function
    returns a list of dictionaries with each list element corresponding to a unique listing. 
    Other functions will take the output from this function and iterate over them to explore
    the details of individual listings.  
    """  
        
    base_url = 'https://www.airbnb.com/s/'
    page_url = '?page='
    
    
    try:
        for n in range(1, loop_limit+1):
            print 'Processing Main Page %s out of %s' % (str(n), str(loop_limit))
            #Implement random time delay for scraping
            sleep(randint(0,2))
            current_url = ''.join([base_url, location_string, page_url, str(n)])
            MainResults += ParseMainXML(current_url, n)
        
            
    except:
        print 'This URL did not return results: %s ' % current_url
    
    print 'Done Processing Main Page'
    return MainResults

# %%
#######################################
#  Main Page    #######################
#######################################


def ParseMainXML(url= 'https://www.airbnb.com/s/Cambridge--MA--United-States', pg = 0):
    
    """
    input: url (string )
            
            this is the url for the type of listings you want to search. 
            default is to use the generic url to search for listings 
            in Cambridge, MA
    input: pg (integer)
        
            this is an integer corresponding to the page number, this is meant
            to be passed in by the wrapper function and collected in the dictionary.
            
    output: dict
    ------
    This funciton parses the main page with mulitple airbnb listings, and 
    returns a list of dictionaries corresponding to the attributes found
    """   
    n = 1
    ListingDB = []
           
    try:
        
        tree = html.fromstring(br.open(url).get_data())
        listings = tree.xpath('//div[@class="listing"]')

        #TODO: add error handling    
        for listing in listings:
            dat = {}
            dat['baseurl'] = url
            dat['Lat'] = listing.attrib.get('data-lat', 'Unknown')
            dat['Long'] = listing.attrib.get('data-lng', 'Unknown')
            dat['Title'] = listing.attrib.get('data-name', 'Unknown')
            dat['ListingID'] = listing.attrib.get('data-id', 'Unknown')
            dat['UserID'] = listing.attrib.get('data-user', 'Unknown')
            dat['Price'] = ''.join(listing.xpath('div//span[@class="h3 text-contrast price-amount"]/text()'))
            dat['PageCounter'] = n
            dat['OverallCounter'] = n * pg
            dat['PageNumber'] = pg
            
            ShortDesc = listing.xpath('div//div[@class="media"]/div/a')
            
            if len(ShortDesc) > 0:
                dat['ShortDesc'] = ShortDesc[0].text
            
            if len(listing.xpath('div/div//span/i')) > 0:
                dat['BookInstantly'] = 'Yes'
            
            else:
                dat['BookInstantly']  = 'No'
                
            ListingDB.append(dat)
            n += 1
        
        return ListingDB
        
    except:
        print 'Error Parsing Page - Skipping: %s' % url
        #if there is an error, just return an empty list
        return ListingDB

# %%
#######################################
#  Detail Pages #######################
#######################################

def iterateDetail(mainResults):
    """
    This function takes the list of dictionaries returned by the
    IterateMainPage, and "enriches" the data with detailed data
    from the particular listing's info - if there is an error
    with getting that particular listing's info, the dictionary
    will be populated with default values of "Not Found"
    """
    finalResults = []
    counter = 0
    baseURL = 'https://www.airbnb.com/rooms/'   
       
    for listing in mainResults:
        counter += 1      
        print 'Processing Listing %s out of %s' % (str(counter), str(len(mainResults)))
        
        #Construct URL
        currentURL = ''.join([baseURL, str(listing['ListingID'])])
        
        #Get the tree         
        tree = getTree(currentURL)
        
        #Parse the data out of the tree      
        DetailResults = collectDetail(tree, listing['ListingID'])
        
        #Collect Data
        newListing = dict(listing.items() + DetailResults.items())
        
        #Append To Final Results
        finalResults.append(newListing)
        
    return finalResults

# %%
def fixDetail(mainResults, indexList):
    
    finalResults = mainResults[:]
    baseURL = 'https://www.airbnb.com/rooms/'   
    
    #redoList = [61, 62, 63, 64, 65, 66, 67, 443, 444, 445, 446, 447, 448, 449, \
    #450, 451, 452, 453, 454, 455, 456, 457, 458, 459]
    
    ######Only Modify This Part When You Want To Redo Certain Listings!!!###
    
    for i in indexList:
        print 'fixing index %s' % str(i) 
        listingID = str(finalResults[i]['ListingID'])
        currentURL = ''.join([baseURL, listingID])
        
        #Get the tree         
        tree = getTree(currentURL)
        
        #Parse the data out of the tree      
        DetailResults = collectDetail(tree, listingID)
        
        #Collect Data
        newListing = dict(finalResults[i].items() + DetailResults.items())
        
        #Append To Final Results
        finalResults[i] = newListing
        
    return finalResults

# %%
def getTree(url):
    """
    input
        url (string): this is a url string.  example: "http://www.google.com"
    
    output
        tree object:  will return a tree object if the url is found, 
        otherwise will return a blank string
    """
    try:
        #Implement random time delay for scraping
        #sleep(randint(0,1))
        tree = html.fromstring(br.open(url).get_data())
        return tree
        
    except:
        #Pass An Empty String And Error Handling Of Children Functions Will Do 
        #Appropriate Things
        print 'Was not able to fetch data from %s' % url
        return ''

# %%
def collectDetail(treeObject, ListingID):
    Results = {'AboutListing': 'Not Found', 
                     'HostName': 'Not Found',
                     'RespRate': 'Not Found',
                     'RespTime': 'Not Found',
                     'MemberDate': 'Not Found',
                     'R_acc' : 'Not Found',
                     'R_comm' : 'Not Found',
                     'R_clean' : 'Not Found',
                     'R_loc': 'Not Found',
                     'R_CI' : 'Not Found',
                     'R_val' : 'Not Found',
                     'P_ExtraPeople' : 'Not Found',
                     'P_Cleaning' : 'Not Found',
                     'P_Deposit' : 'Not Found',
                     'P_Weekly' : 'Not Found',
                     'P_Monthly' : 'Not Found',
                     'Cancellation' : 'Not Found',
                     'A_Kitchen' : 0,
                     'A_Internet' : 0,
                     'A_TV' : 0, 
                     'A_Essentials' : 0,
                     'A_Shampoo' : 0,
                     'A_Heat' : 0,
                     'A_AC' : 0,
                     'A_Washer' : 0,
                     'A_Dryer' : 0,
                     'A_Parking' : 0,
                     'A_Internet' : 0,
                     'A_CableTV' : 0,
                     'A_Breakfast' :  0,
                     'A_Pets' : 0,
                     'A_FamilyFriendly' : 0,
                     'A_Events' : 0,
                     'A_Smoking' : 0,
                     'A_Wheelchair' : 0,
                     'A_Elevator' : 0,
                     'A_Fireplace' : 0,
                     'A_Intercom' : 0,
                     'A_Doorman' : 0, 
                     'A_Pool' : 0,
                     'A_HotTub' : 0,
                     'A_Gym' : 0,
                     'A_SmokeDetector' : 0,
                     'A_CarbonMonoxDetector' : 0,
                     'A_FirstAidKit' : 0,
                     'A_SafetyCard' : 0,
                     'A_FireExt' : 0, 
                     'S_PropType' : 'Not Found',
                     'S_Accomodates' : 'Not Found',
                     'S_Bedrooms' : 'Not Found',
                     'S_Bathrooms' : 'Not Found',
                     'S_NumBeds' : 'Not Found',
                     'S_BedType' : 'Not Found',
                     'S_CheckIn' : 'Not Found',
                     'S_Checkout' : 'Not Found'
                     }   
    try: 
        #Hamel's Functions
        ###################                    
        Results['AboutListing'] = getAboutListing(treeObject, ListingID)
        Space = getSpaceInfo(treeObject, ListingID)
        Results['S_PropType'] = Space['PropType']
        Results['S_Accomodates'] = Space['Accommodates']
        Results['S_Bedrooms'] = Space['Bedrooms']
        Results['S_Bathrooms'] = Space['Bathrooms'] 
        Results['S_NumBeds'] = Space['NumBeds']
        Results['S_BedType'] = Space['BedType']
        Results['S_CheckIn'] = Space['CheckIn']
        Results['S_Checkout'] = Space['CheckOut']
            
        
        
        #Yi's Functions
        ####################
        Results['HostName'] = getHostName(TreeToSoup(treeObject), ListingID)
        Results['RespRate'], Results['RespTime'] = getHostResponse(TreeToSoup(treeObject), ListingID)
        Results['MemberDate'] = getMemberDate(TreeToSoup(treeObject), ListingID)
        
        #accuracy, communication, cleanliness, location, checkin, value
        Results['R_acc'], Results['R_comm'], Results['R_clean'], Results['R_loc'], \
        Results['R_CI'], Results['R_val'] = getStars(TreeToSoup(treeObject), ListingID)
        
        #price
        PriceData = getPriceInfo(treeObject, ListingID)
        Results['P_ExtraPeople'] = PriceData['ExtraPeople']
        Results['P_Cleaning'] = PriceData['CleaningFee']
        Results['P_Deposit'] = PriceData['SecurityDeposit']
        Results['P_Weekly'] = PriceData['WeeklyPrice']
        Results['P_Monthly'] = PriceData['MonthlyPrice'] 
        Results['Cancellation'] = PriceData['Cancellation']
        
        #Amenities
        Am = getAmenities(treeObject, ListingID)
        Results['A_Kitchen'] = Am['Kitchen']
        Results['A_Internet'] = Am['Internet']
        Results['A_TV'] = Am['TV'] 
        Results['A_Essentials'] = Am['Essentials' ]
        Results['A_Shampoo'] = Am['Shampoo'] 
        Results['A_Heat'] = Am['Heating'] 
        Results['A_AC'] = Am['Air Conditioning'] 
        Results['A_Washer'] = Am['Washer'] 
        Results['A_Dryer'] = Am['Dryer'] 
        Results['A_Parking'] = Am['Free Parking on Premises'] 
        Results['A_Internet'] = Am['Wireless Internet'] 
        Results['A_CableTV'] = Am['Cable TV' ]
        Results['A_Breakfast'] =  Am['Breakfast'] 
        Results['A_Pets'] = Am['Pets Allowed'] 
        Results['A_FamilyFriendly'] = Am['Family/Kid Friendly'] 
        Results['A_Events'] = Am['Suitable for Events']
        Results['A_Smoking'] = Am['Smoking Allowed'] 
        Results['A_Wheelchair'] = Am['Wheelchair Accessible'] 
        Results['A_Elevator'] = Am['Elevator in Building'] 
        Results['A_Fireplace'] = Am['Indoor Fireplace' ]
        Results['A_Intercom'] = Am['Buzzer/Wireless Intercom'] 
        Results['A_Doorman'] = Am['Doorman'] 
        Results['A_Pool'] = Am['Pool'] 
        Results['A_HotTub'] = Am['Hot Tub'] 
        Results['A_Gym'] = Am['Gym']
        Results['A_SmokeDetector'] = Am['Smoke Detector'] 
        Results['A_CarbonMonoxDetector'] = Am['Carbon Monoxide Detector'] 
        Results['A_FirstAidKit'] = Am['First Aid Kit' ]
        Results['A_SafetyCard'] = Am['Safety Card'] 
        Results['A_FireExt'] = Am['Fire Extinguisher'] 
        return Results
        
    except:
        #Just Return Initialized Dictionary
        return Results

# %%
def TreeToSoup(treeObject):
    """
    input: HTML element tree
    output: soup object (Beautiful Soup)
    This function converts an HTML element tree to a soup object
    """
    source = tostring(treeObject)
    soup = bs4.BeautifulSoup(source)
    return soup

# %%
def getHostName(soup, ListingID): 
    """
    Written by Yi
    """
    host_name = 'Not Found'
    
    try:
        host_name = soup.find_all("h4", {"class" : "row-space-4"})[2].text.strip("\n ").encode('utf8')
        host_name = host_name.split(", ")[1]
        return host_name
    
    except:
        print 'Unable to parse host name for listing id: %s' % str(ListingID)
        return host_name

# %%
def getHostResponse(soup, ListingID):
    """
    Written by Yi
    """
    response_rate, response_time = ['Not Found'] * 2
    
    try:
        host_member = soup.find_all("div", {"class" : "col-6"})[-1]
        response_rate = host_member.find_all("strong")[0].text.encode('utf8')
        response_time = host_member.find_all("strong")[1].text.encode('utf8')
        return response_rate, response_time          
        
    except:
        print 'Unable to parse response time for listing id: %s' % str(ListingID)
        return response_rate, response_time

# %%
def getMemberDate(soup, ListingID):
    """
    Written by Yi
    """
    membership_date = 'Not Found'    
    
    try:
        host_member = soup.find_all("div", {"class" : "col-6"})[-2]
        membership_date = host_member.find_all("div")[1].text.encode('utf8').strip("\n ")
        membership_date = membership_date.replace("Member since", "")
        return membership_date
        
    except:
        print 'Unable to parse membership date for listing id: %s' % str(ListingID)
        return membership_date

# %%
def singlestar(index, soup):
    """
    Written by Yi
    """
    stars = soup.find_all("div", {"class" : "foreground"})[index]
    full_star = stars.find_all("i", {"class" : "icon icon-pink icon-beach icon-star"})
    half_star=  stars.find_all("i", {"class" : "icon icon-pink icon-beach icon-star-half"})
    total_star = len(full_star)+len(half_star)*0.5
    return total_star

# %%
def getStars(soup, ListingID):
    """
    Written by Yi
    """
    accuracy, communication, cleanliness, location, checkin, value = ['Not Found'] * 6
    
    try:
        #accuracy starts at the thrid stars, right after the total reviews 
        accuracy = singlestar(2, soup)
        communication = singlestar(3, soup)
        cleanliness = singlestar(4, soup)
        location = singlestar(5,soup)
        checkin = singlestar(6,soup)
        value = singlestar(7,soup)
        return accuracy, communication, cleanliness, location, checkin, value
    
    except:
        print 'Unable to parse stars listing id: %s' % str(ListingID)
        return accuracy, communication, cleanliness, location, checkin, value

# %%
#########################################
## Hamel's Functions ####################     

def getAboutListing(tree, ListingID):
    """
    input: xmltree object
    output: string
    -----------------
    This function parses an individual listing's page to find 
    the "About This Listing" and extracts the associated text
    """  
    try:
    #Go To The Panel-Body
        elements = tree.xpath('//div[@class="panel-body"]/h4')

        #Search For "About This Listing" In Elements    
        for element in elements:
            if element.text.find('About This Listing') >= 0:
                #When You Find, it return the text that comes afterwards
                return element.getnext().text

    except:
        print 'Error finding *About Listing* for listing ID: %s' % ListingID
        return 'No Description Found'

# %%
def getSpaceInfo(tree, ListingID = 'Test'):  
    
    """
    input: xmltree object
    output: dict
    -----------------
    This function parses an individual listing's page to find 
    the all of the data in the "Space" row, such as Number of 
    Bedrooms, Number of Bathrooms, Check In/Out Time, etc.
    """ 
    #Initialize Values
    dat = {'PropType': 'Not Found', 'Accommodates': 'Not Found', 
           'Bedrooms': 'Not Found', 'Bathrooms' : 'Not Found',
           'NumBeds': 'Not Found', 'BedType': 'Not Found', 
           'CheckIn': 'Not Found', 'CheckOut': 'Not Found'}    
    
    try:
        #Get Nodes That Contain The Grey Text, So That You Can Search For Sections
        elements = tree.xpath('//div[@class="row"]/div[@class="col-md-3"]/div[@class="text-muted"]')
    
          #find The space portion of the page, 
          #then go back up one level and sideways one level
        for element in elements:
          
            if element.text.find('The Space') >= 0:
                #If you find what you are looking for Go Up One Level Then Go Sideways
                targetelement = element.getparent().getnext()
                break
            
        #Depth - First Search of The Target Node
        descendants = targetelement.iterdescendants()
        
        for descendant in descendants:
            #check to make sure there is text in descendant
            if descendant.text:                
                ##Find Property Type##
                if descendant.text.find('Property type:') >= 0:  
                    prop =  descendant.xpath('.//strong/*')
                
                    if len(prop) >= 1:
                        dat['PropType'] = prop[0].text
                
                ##Find Accomodates ####
                if descendant.text.find('Accommodates:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['Accommodates'] = prop[0].text
                        
                ##Find Bedrooms ####
                if descendant.text.find('Bedrooms:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['Bedrooms'] = prop[0].text
                        
                ##Find Bathrooms ####
                if descendant.text.find('Bathrooms:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['Bathrooms'] = prop[0].text
                        
                ##Find Number of Beds ####
                if descendant.text.find('Beds:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['NumBeds'] = prop[0].text
               
               ##Find Bed Type ####
                if descendant.text.find('Bed type:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['BedType'] = prop[0].text               
               
               ##Find Check In Time ####
                if descendant.text.find('Check In:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['CheckIn'] = prop[0].text  
                
                ##Find Check Out Time ####
                if descendant.text.find('Check Out:') >= 0:
                    prop =  descendant.xpath('.//strong')
                    if len(prop) >= 1:
                        dat['CheckOut'] = prop[0].text   
        return dat
        
    except:
        print 'Error in getting Space Elements for listing iD: %s' % str(ListingID)
        return dat

# %%
def getPriceInfo(tree, ListingID):      
    """
    input: xmltree object
    output: dict
    -----------------
    This function parses an individual listing's page to find 
    the all of the data in the "Price" row, such as Cleaning Fee, Security Deposit, Weekly Price, etc.
    """ 
    #Initialize Values
    dat = {'ExtraPeople': 'Not Found', 'CleaningFee': 'Not Found', 'SecurityDeposit': 'Not Found', 
       'WeeklyPrice': 'Not Found','MonthlyPrice': 'Not Found','Cancellation' : 'Not Found'} 
    
    try:
        #Get Nodes That Contain The Grey Text, So That You Can Search For Sections
        elements = tree.xpath('//*[@class="text-muted"]')
    
          #find The price portion of the page, 
          #then go back up one level and sideways one level
        for element in elements:
          
            if element.text.find('Prices') >= 0:
                #If you find what you are looking for Go Up One Level Then Go Sideways
                targetelement = element.getparent().getnext()
                break
            
        #Depth - First Search of The Target Node
        descendants = targetelement.iterdescendants()
        
        for descendant in descendants:
            #check to make sure there is text in descendant
            if descendant.text:                
                ##Find Extra People Free ##
                if descendant.text.find('Extra people:') >= 0:  
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['ExtraPeople'] = prop[0].text
                
                ##Find Cleaning Fee ####
                if descendant.text.find('Cleaning Fee:') >= 0:
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['CleaningFee'] = prop[0].text
                        
                ##Find Security Deposit ####
                if descendant.text.find('Security Deposit:') >= 0:
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['SecurityDeposit'] = prop[0].text
                        
                ##Find Weekly Price ####
                if descendant.text.find('Weekly Price:') >= 0:
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['WeeklyPrice'] = prop[0].text
                        
                ##Find Monthly Price ####
                if descendant.text.find('Monthly Price:') >= 0:
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['MonthlyPrice'] = prop[0].text
                
                ##Find Cancellation ####
                if descendant.text.find('Cancellation:') >= 0:
                    prop =  descendant.xpath('.//strong/*')
                    if len(prop) >= 1:
                        dat['Cancellation'] = prop[0].text  
        return dat
        
    except:
        print 'Error in getting Space Elements for listing iD: %s' % str(ListingID)
        return dat

# %%
def getAmenitiesList(tree, ListingID):
    """
    input: xmltree object
    output: list of available amenities
    -----------------
    This function parses an individual listing's page to find 
    the amenities available in the listing.  The amenities that are available
    are collected into a list.
    """ 
    amenities = []
    
    try:
        #Get Nodes That Contain The Grey Text, So That You Can Search For Sections
        elements = tree.xpath('//*[@class="text-muted"]')
        
          #find The price portion of the page, 
          #then go back up one level and sideways one level
        for element in elements:
          
            if element.text.find('Amenities') >= 0:
                #If you find what you are looking for Go Up One Level Then Go Sideways
                targetelement = element.getparent().getnext()
                break
        
        content = targetelement.xpath('//*[@class="expandable-content-full"]')
        
        
        if len(content) >= 1:
            for amenity in content[0].xpath('.//span/strong/text()'):
                amenities.append(amenity.strip())
                
        return list(set(amenities))
    
    except:
        print 'Error in getting amenities for listing iD: %s' % str(ListingID)
        return amenities

# %%
def getAmenities(tree, ListingID):
    """
    input: xmltree object
    output: dict of binary indication if amenity exists or not
    -----------------
    This function parses an individual listing's page to find 
    the amenities available in the listing.  The amenities that are available
    are collected into a list.
    """     
       
       #Initialize Values
    dat = {'Kitchen': 0, 'Internet': 0, 'TV': 0, 'Essentials' : 0,
           'Shampoo': 0, 'Heating': 0, 'Air Conditioning': 0, 'Washer': 0, 
           'Dryer': 0, 'Free Parking on Premises': 0, 
           'Wireless Internet': 0, 'Cable TV' : 0,'Breakfast': 0, 'Pets Allowed': 0, 
           'Family/Kid Friendly': 0, 'Suitable for Events': 0,
           'Smoking Allowed': 0, 'Wheelchair Accessible': 0, 
           'Elevator in Building': 0, 'Indoor Fireplace' : 0,
           'Buzzer/Wireless Intercom': 0, 'Doorman': 0, 
           'Pool': 0, 'Hot Tub': 0, 'Gym': 0,'Smoke Detector': 0, 
           'Carbon Monoxide Detector': 0, 'First Aid Kit' : 0,
           'Safety Card': 0, 'Fire Extinguisher': 0}    
           
    amenities = getAmenitiesList(tree, ListingID)
    
    for amenity in dat.keys():
        if amenity in amenities:
            dat[amenity] = 1
    
    return dat

# %%
class DictUnicodeWriter(object):

    def __init__(self, f, fieldnames, dialect=csv.excel, encoding="utf-8", **kwds):
        # Redirect output to a queue
        self.queue = cStringIO.StringIO()
        self.writer = csv.DictWriter(self.queue, fieldnames, dialect=dialect, **kwds)
        self.stream = f
        self.encoder = codecs.getincrementalencoder(encoding)()

    def writerow(self, D):
        self.writer.writerow({k:v.encode("utf-8") if isinstance(v, unicode) else v for k,v in D.items()})
        # Fetch UTF-8 output from the queue ...
        data = self.queue.getvalue()
        data = data.decode("utf-8")
        # ... and reencode it into the target encoding
        data = self.encoder.encode(data)
        # write to the target stream
        self.stream.write(data)
        # empty queue
        self.queue.truncate(0)

    def writerows(self, rows):
        for D in rows:
            self.writerow(D)

    def writeheader(self):
        self.writer.writeheader()

def writeToCSV(resultDict, outfile):
    
    colnames = [ 'ListingID', 'Title','UserID','baseurl',  'Price', \
        'AboutListing','HostName', 'MemberDate', 'Lat','Long','BookInstantly','Cancellation',  \
        'OverallCounter','PageCounter','PageNumber', \
         'A_AC','A_Breakfast','A_CableTV','A_CarbonMonoxDetector','A_Doorman','A_Dryer','A_TV', \
         'A_Elevator','A_Essentials','A_Events','A_FamilyFriendly','A_FireExt','A_Fireplace','A_FirstAidKit', \
         'A_Gym','A_Heat','A_HotTub','A_Intercom','A_Internet','A_Kitchen','A_Parking','A_Pets','A_Pool','A_SafetyCard', \
         'A_Shampoo','A_SmokeDetector','A_Smoking','A_Washer','A_Wheelchair', \
         'P_Cleaning','P_Deposit','P_ExtraPeople','P_Monthly','P_Weekly', \
         'R_CI','R_acc','R_clean','R_comm', \
         'R_loc','R_val', \
         'RespRate','RespTime', \
         'S_Accomodates','S_Bathrooms','S_BedType','S_Bedrooms', \
         'S_CheckIn','S_Checkout','S_NumBeds','S_PropType','ShortDesc']
        
    with open(outfile, 'wb') as f:
        w = DictUnicodeWriter(f, fieldnames=colnames)
        w.writeheader()
        w.writerows(resultDict)

# %%
if __name__ == '__main__':
    
    #Iterate Through Main Page To Get Results
    MainResults = IterateMainPage('San-Francisco--CA', 56)
# Out:
# Processing Main Page 1 out of 56
# Processing Main Page 2 out of 56
# Processing Main Page 3 out of 56
# Processing Main Page 4 out of 56
# Processing Main Page 5 out of 56
# Processing Main Page 6 out of 56
# Processing Main Page 7 out of 56
# Processing Main Page 8 out of 56
# Processing Main Page 9 out of 56
# Processing Main Page 10 out of 56
# Processing Main Page 11 out of 56
# Processing Main Page 12 out of 56
# Processing Main Page 13 out of 56
# Processing Main Page 14 out of 56
# Processing Main Page 15 out of 56
# Processing Main Page 16 out of 56
# Processing Main Page 17 out of 56
# Processing Main Page 18 out of 56
# Processing Main Page 19 out of 56
# Processing Main Page 20 out of 56
# Processing Main Page 21 out of 56
# Processing Main Page 22 out of 56
# Processing Main Page 23 out of 56
# Processing Main Page 24 out of 56
# Processing Main Page 25 out of 56
# Processing Main Page 26 out of 56
# Processing Main Page 27 out of 56
# Processing Main Page 28 out of 56
# Processing Main Page 29 out of 56
# Processing Main Page 30 out of 56
# Processing Main Page 31 out of 56
# Processing Main Page 32 out of 56
# Processing Main Page 33 out of 56
# Processing Main Page 34 out of 56
# Processing Main Page 35 out of 56
# Processing Main Page 36 out of 56
# Processing Main Page 37 out of 56
# Processing Main Page 38 out of 56
# Processing Main Page 39 out of 56
# Processing Main Page 40 out of 56
# Processing Main Page 41 out of 56
# Processing Main Page 42 out of 56
# Processing Main Page 43 out of 56
# Processing Main Page 44 out of 56
# Processing Main Page 45 out of 56
# Processing Main Page 46 out of 56
# Processing Main Page 47 out of 56
# Processing Main Page 48 out of 56
# Processing Main Page 49 out of 56
# Processing Main Page 50 out of 56
# Processing Main Page 51 out of 56
# Processing Main Page 52 out of 56
# Processing Main Page 53 out of 56
# Processing Main Page 54 out of 56
# Processing Main Page 55 out of 56
# Processing Main Page 56 out of 56
# Done Processing Main Page

# %%
 #Take The Main Results From Previous Step and Iterate Through Each Listing
    #To add more detail
DetailResults = iterateDetail(MainResults)
# Out:
# Processing Listing 1 out of 1008
# Unable to parse response time for listing id: 3962084
# Unable to parse membership date for listing id: 3962084
# Error in getting amenities for listing iD: 3962084
# Processing Listing 2 out of 1008
# Unable to parse response time for listing id: 33577
# Unable to parse membership date for listing id: 33577
# Error in getting amenities for listing iD: 33577
# Processing Listing 3 out of 1008
# Unable to parse response time for listing id: 200281
# Unable to parse membership date for listing id: 200281
# Error in getting amenities for listing iD: 200281
# Processing Listing 4 out of 1008
# Unable to parse response time for listing id: 4122671
# Unable to parse membership date for listing id: 4122671
# Error in getting amenities for listing iD: 4122671
# Processing Listing 5 out of 1008
# Unable to parse response time for listing id: 8739
# Unable to parse membership date for listing id: 8739
# Error in getting amenities for listing iD: 8739
# Processing Listing 6 out of 1008
# Unable to parse response time for listing id: 8134220
# Unable to parse membership date for listing id: 8134220
# Unable to parse stars listing id: 8134220
# Error in getting amenities for listing iD: 8134220
# Processing Listing 7 out of 1008
# Unable to parse response time for listing id: 6688374
# Unable to parse membership date for listing id: 6688374
# Error in getting amenities for listing iD: 6688374
# Processing Listing 8 out of 1008
# Unable to parse response time for listing id: 6596859
# Unable to parse membership date for listing id: 6596859
# Error in getting amenities for listing iD: 6596859
# Processing Listing 9 out of 1008
# Unable to parse response time for listing id: 7984883
# Unable to parse membership date for listing id: 7984883
# Error in getting amenities for listing iD: 7984883
# Processing Listing 10 out of 1008
# Unable to parse response time for listing id: 7482356
# Unable to parse membership date for listing id: 7482356
# Error in getting amenities for listing iD: 7482356
# Processing Listing 11 out of 1008
# Unable to parse response time for listing id: 6884320
# Unable to parse membership date for listing id: 6884320
# Error in getting amenities for listing iD: 6884320
# Processing Listing 12 out of 1008
# Unable to parse response time for listing id: 713877
# Unable to parse membership date for listing id: 713877
# Error in getting amenities for listing iD: 713877
# Processing Listing 13 out of 1008
# Unable to parse response time for listing id: 44323
# Unable to parse membership date for listing id: 44323
# Error in getting amenities for listing iD: 44323
# Processing Listing 14 out of 1008
# Unable to parse response time for listing id: 173464
# Unable to parse membership date for listing id: 173464
# Error in getting amenities for listing iD: 173464
# Processing Listing 15 out of 1008
# Unable to parse response time for listing id: 4198069
# Unable to parse membership date for listing id: 4198069
# Error in getting amenities for listing iD: 4198069
# Processing Listing 16 out of 1008
# Unable to parse response time for listing id: 1093088
# Unable to parse membership date for listing id: 1093088
# Error in getting amenities for listing iD: 1093088
# Processing Listing 17 out of 1008
# Unable to parse response time for listing id: 205842
# Unable to parse membership date for listing id: 205842
# Error in getting amenities for listing iD: 205842
# Processing Listing 18 out of 1008
# Unable to parse response time for listing id: 33578
# Unable to parse membership date for listing id: 33578
# Error in getting amenities for listing iD: 33578
# Processing Listing 19 out of 1008
# Unable to parse response time for listing id: 19756
# Unable to parse membership date for listing id: 19756
# Error in getting amenities for listing iD: 19756
# Processing Listing 20 out of 1008
# Unable to parse response time for listing id: 918341
# Unable to parse membership date for listing id: 918341
# Error in getting amenities for listing iD: 918341
# Processing Listing 21 out of 1008
# Unable to parse response time for listing id: 567239
# Unable to parse membership date for listing id: 567239
# Error in getting amenities for listing iD: 567239
# Processing Listing 22 out of 1008
# Unable to parse response time for listing id: 7462935
# Unable to parse membership date for listing id: 7462935
# Error in getting amenities for listing iD: 7462935
# Processing Listing 23 out of 1008
# Unable to parse response time for listing id: 4387067
# Unable to parse membership date for listing id: 4387067
# Error in getting amenities for listing iD: 4387067
# Processing Listing 24 out of 1008
# Unable to parse response time for listing id: 7222704
# Unable to parse membership date for listing id: 7222704
# Error in getting amenities for listing iD: 7222704
# Processing Listing 25 out of 1008
# Unable to parse response time for listing id: 8155582
# Unable to parse membership date for listing id: 8155582
# Unable to parse stars listing id: 8155582
# Error in getting amenities for listing iD: 8155582
# Processing Listing 26 out of 1008
# Unable to parse response time for listing id: 4069917
# Unable to parse membership date for listing id: 4069917
# Error in getting amenities for listing iD: 4069917
# Processing Listing 27 out of 1008
# Unable to parse response time for listing id: 164207
# Unable to parse membership date for listing id: 164207
# Error in getting amenities for listing iD: 164207
# Processing Listing 28 out of 1008
# Unable to parse response time for listing id: 5903014
# Unable to parse membership date for listing id: 5903014
# Error in getting amenities for listing iD: 5903014
# Processing Listing 29 out of 1008
# Unable to parse response time for listing id: 26843
# Unable to parse membership date for listing id: 26843
# Error in getting amenities for listing iD: 26843
# Processing Listing 30 out of 1008
# Unable to parse response time for listing id: 7638622
# Unable to parse membership date for listing id: 7638622
# Unable to parse stars listing id: 7638622
# Error in getting amenities for listing iD: 7638622
# Processing Listing 31 out of 1008
# Unable to parse response time for listing id: 51073
# Unable to parse membership date for listing id: 51073
# Error in getting amenities for listing iD: 51073
# Processing Listing 32 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/150848
# Error finding *About Listing* for listing ID: 150848
# Error in getting Space Elements for listing iD: 150848
# Processing Listing 33 out of 1008
# Unable to parse response time for listing id: 3416013
# Unable to parse membership date for listing id: 3416013
# Error in getting amenities for listing iD: 3416013
# Processing Listing 34 out of 1008
# Unable to parse response time for listing id: 937842
# Unable to parse membership date for listing id: 937842
# Error in getting amenities for listing iD: 937842
# Processing Listing 35 out of 1008
# Unable to parse response time for listing id: 748256
# Unable to parse membership date for listing id: 748256
# Error in getting amenities for listing iD: 748256
# Processing Listing 36 out of 1008
# Unable to parse response time for listing id: 5013816
# Unable to parse membership date for listing id: 5013816
# Error in getting amenities for listing iD: 5013816
# Processing Listing 37 out of 1008
# Unable to parse response time for listing id: 1280597
# Unable to parse membership date for listing id: 1280597
# Error in getting amenities for listing iD: 1280597
# Processing Listing 38 out of 1008
# Unable to parse response time for listing id: 5552105
# Unable to parse membership date for listing id: 5552105
# Error in getting amenities for listing iD: 5552105
# Processing Listing 39 out of 1008
# Unable to parse response time for listing id: 8028929
# Unable to parse membership date for listing id: 8028929
# Unable to parse stars listing id: 8028929
# Error in getting amenities for listing iD: 8028929
# Processing Listing 40 out of 1008
# Unable to parse response time for listing id: 5154242
# Unable to parse membership date for listing id: 5154242
# Error in getting amenities for listing iD: 5154242
# Processing Listing 41 out of 1008
# Unable to parse response time for listing id: 1427660
# Unable to parse membership date for listing id: 1427660
# Error in getting amenities for listing iD: 1427660
# Processing Listing 42 out of 1008
# Unable to parse response time for listing id: 208831
# Unable to parse membership date for listing id: 208831
# Error in getting amenities for listing iD: 208831
# Processing Listing 43 out of 1008
# Unable to parse response time for listing id: 12522
# Unable to parse membership date for listing id: 12522
# Error in getting amenities for listing iD: 12522
# Processing Listing 44 out of 1008
# Unable to parse response time for listing id: 5496781
# Unable to parse membership date for listing id: 5496781
# Unable to parse stars listing id: 5496781
# Error in getting amenities for listing iD: 5496781
# Processing Listing 45 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/7229079
# Error finding *About Listing* for listing ID: 7229079
# Error in getting Space Elements for listing iD: 7229079
# Processing Listing 46 out of 1008
# Unable to parse response time for listing id: 24463
# Unable to parse membership date for listing id: 24463
# Error in getting amenities for listing iD: 24463
# Processing Listing 47 out of 1008
# Unable to parse response time for listing id: 7948450
# Unable to parse membership date for listing id: 7948450
# Unable to parse stars listing id: 7948450
# Error in getting amenities for listing iD: 7948450
# Processing Listing 48 out of 1008
# Unable to parse response time for listing id: 470686
# Unable to parse membership date for listing id: 470686
# Error in getting amenities for listing iD: 470686
# Processing Listing 49 out of 1008
# Unable to parse response time for listing id: 2393583
# Unable to parse membership date for listing id: 2393583
# Error in getting amenities for listing iD: 2393583
# Processing Listing 50 out of 1008
# Unable to parse response time for listing id: 2160741
# Unable to parse membership date for listing id: 2160741
# Error in getting amenities for listing iD: 2160741
# Processing Listing 51 out of 1008
# Unable to parse response time for listing id: 5491995
# Unable to parse membership date for listing id: 5491995
# Error in getting amenities for listing iD: 5491995
# Processing Listing 52 out of 1008
# Unable to parse response time for listing id: 242614
# Unable to parse membership date for listing id: 242614
# Error in getting amenities for listing iD: 242614
# Processing Listing 53 out of 1008
# Unable to parse response time for listing id: 3265029
# Unable to parse membership date for listing id: 3265029
# Error in getting amenities for listing iD: 3265029
# Processing Listing 54 out of 1008
# Unable to parse response time for listing id: 4156390
# Unable to parse membership date for listing id: 4156390
# Error in getting amenities for listing iD: 4156390
# Processing Listing 55 out of 1008
# Unable to parse response time for listing id: 7676542
# Unable to parse membership date for listing id: 7676542
# Unable to parse stars listing id: 7676542
# Error in getting amenities for listing iD: 7676542
# Processing Listing 56 out of 1008
# Unable to parse response time for listing id: 269097
# Unable to parse membership date for listing id: 269097
# Error in getting amenities for listing iD: 269097
# Processing Listing 57 out of 1008
# Unable to parse response time for listing id: 1677907
# Unable to parse membership date for listing id: 1677907
# Error in getting amenities for listing iD: 1677907
# Processing Listing 58 out of 1008
# Unable to parse response time for listing id: 3486460
# Unable to parse membership date for listing id: 3486460
# Error in getting amenities for listing iD: 3486460
# Processing Listing 59 out of 1008
# Unable to parse response time for listing id: 727866
# Unable to parse membership date for listing id: 727866
# Error in getting amenities for listing iD: 727866
# Processing Listing 60 out of 1008
# Unable to parse response time for listing id: 7842054
# Unable to parse membership date for listing id: 7842054
# Error in getting amenities for listing iD: 7842054
# Processing Listing 61 out of 1008
# Unable to parse response time for listing id: 89616
# Unable to parse membership date for listing id: 89616
# Error in getting amenities for listing iD: 89616
# Processing Listing 62 out of 1008
# Unable to parse response time for listing id: 584402
# Unable to parse membership date for listing id: 584402
# Error in getting amenities for listing iD: 584402
# Processing Listing 63 out of 1008
# Unable to parse response time for listing id: 24723
# Unable to parse membership date for listing id: 24723
# Error in getting amenities for listing iD: 24723
# Processing Listing 64 out of 1008
# Unable to parse response time for listing id: 6728250
# Unable to parse membership date for listing id: 6728250
# Error in getting amenities for listing iD: 6728250
# Processing Listing 65 out of 1008
# Unable to parse response time for listing id: 5920507
# Unable to parse membership date for listing id: 5920507
# Unable to parse stars listing id: 5920507
# Error in getting amenities for listing iD: 5920507
# Processing Listing 66 out of 1008
# Unable to parse response time for listing id: 311259
# Unable to parse membership date for listing id: 311259
# Error in getting amenities for listing iD: 311259
# Processing Listing 67 out of 1008
# Unable to parse response time for listing id: 2046634
# Unable to parse membership date for listing id: 2046634
# Error in getting amenities for listing iD: 2046634
# Processing Listing 68 out of 1008
# Unable to parse response time for listing id: 748222
# Unable to parse membership date for listing id: 748222
# Error in getting amenities for listing iD: 748222
# Processing Listing 69 out of 1008
# Unable to parse response time for listing id: 664307
# Unable to parse membership date for listing id: 664307
# Error in getting amenities for listing iD: 664307
# Processing Listing 70 out of 1008
# Unable to parse response time for listing id: 5196233
# Unable to parse membership date for listing id: 5196233
# Error in getting amenities for listing iD: 5196233
# Processing Listing 71 out of 1008
# Unable to parse response time for listing id: 510733
# Unable to parse membership date for listing id: 510733
# Unable to parse stars listing id: 510733
# Error in getting amenities for listing iD: 510733
# Processing Listing 72 out of 1008
# Unable to parse response time for listing id: 4962043
# Unable to parse membership date for listing id: 4962043
# Error in getting amenities for listing iD: 4962043
# Processing Listing 73 out of 1008
# Unable to parse response time for listing id: 7562249
# Unable to parse membership date for listing id: 7562249
# Unable to parse stars listing id: 7562249
# Error in getting amenities for listing iD: 7562249
# Processing Listing 74 out of 1008
# Unable to parse response time for listing id: 467507
# Unable to parse membership date for listing id: 467507
# Error in getting amenities for listing iD: 467507
# Processing Listing 75 out of 1008
# Unable to parse response time for listing id: 1533378
# Unable to parse membership date for listing id: 1533378
# Error in getting amenities for listing iD: 1533378
# Processing Listing 76 out of 1008
# Unable to parse response time for listing id: 7180020
# Unable to parse membership date for listing id: 7180020
# Error in getting amenities for listing iD: 7180020
# Processing Listing 77 out of 1008
# Unable to parse response time for listing id: 5299538
# Unable to parse membership date for listing id: 5299538
# Error in getting amenities for listing iD: 5299538
# Processing Listing 78 out of 1008
# Unable to parse response time for listing id: 980240
# Unable to parse membership date for listing id: 980240
# Error in getting amenities for listing iD: 980240
# Processing Listing 79 out of 1008
# Unable to parse response time for listing id: 8162897
# Unable to parse membership date for listing id: 8162897
# Unable to parse stars listing id: 8162897
# Error in getting amenities for listing iD: 8162897
# Processing Listing 80 out of 1008
# Unable to parse response time for listing id: 1510363
# Unable to parse membership date for listing id: 1510363
# Error in getting amenities for listing iD: 1510363
# Processing Listing 81 out of 1008
# Unable to parse response time for listing id: 992676
# Unable to parse membership date for listing id: 992676
# Error in getting amenities for listing iD: 992676
# Processing Listing 82 out of 1008
# Unable to parse response time for listing id: 7462925
# Unable to parse membership date for listing id: 7462925
# Error in getting amenities for listing iD: 7462925
# Processing Listing 83 out of 1008
# Unable to parse response time for listing id: 5650515
# Unable to parse membership date for listing id: 5650515
# Error in getting amenities for listing iD: 5650515
# Processing Listing 84 out of 1008
# Unable to parse response time for listing id: 4792110
# Unable to parse membership date for listing id: 4792110
# Error in getting amenities for listing iD: 4792110
# Processing Listing 85 out of 1008
# Unable to parse response time for listing id: 5838639
# Unable to parse membership date for listing id: 5838639
# Error in getting amenities for listing iD: 5838639
# Processing Listing 86 out of 1008
# Unable to parse response time for listing id: 585225
# Unable to parse membership date for listing id: 585225
# Error in getting amenities for listing iD: 585225
# Processing Listing 87 out of 1008
# Unable to parse response time for listing id: 1692470
# Unable to parse membership date for listing id: 1692470
# Error in getting amenities for listing iD: 1692470
# Processing Listing 88 out of 1008
# Unable to parse response time for listing id: 187875
# Unable to parse membership date for listing id: 187875
# Error in getting amenities for listing iD: 187875
# Processing Listing 89 out of 1008
# Unable to parse response time for listing id: 6305740
# Unable to parse membership date for listing id: 6305740
# Error in getting amenities for listing iD: 6305740
# Processing Listing 90 out of 1008
# Unable to parse response time for listing id: 129515
# Unable to parse membership date for listing id: 129515
# Error in getting amenities for listing iD: 129515
# Processing Listing 91 out of 1008
# Unable to parse response time for listing id: 515654
# Unable to parse membership date for listing id: 515654
# Error in getting amenities for listing iD: 515654
# Processing Listing 92 out of 1008
# Unable to parse response time for listing id: 6926410
# Unable to parse membership date for listing id: 6926410
# Error in getting amenities for listing iD: 6926410
# Processing Listing 93 out of 1008
# Unable to parse response time for listing id: 4053544
# Unable to parse membership date for listing id: 4053544
# Unable to parse stars listing id: 4053544
# Error in getting amenities for listing iD: 4053544
# Processing Listing 94 out of 1008
# Unable to parse response time for listing id: 2956406
# Unable to parse membership date for listing id: 2956406
# Error in getting amenities for listing iD: 2956406
# Processing Listing 95 out of 1008
# Unable to parse response time for listing id: 2496086
# Unable to parse membership date for listing id: 2496086
# Error in getting amenities for listing iD: 2496086
# Processing Listing 96 out of 1008
# Unable to parse response time for listing id: 5642608
# Unable to parse membership date for listing id: 5642608
# Error in getting amenities for listing iD: 5642608
# Processing Listing 97 out of 1008
# Unable to parse response time for listing id: 7604679
# Unable to parse membership date for listing id: 7604679
# Error in getting amenities for listing iD: 7604679
# Processing Listing 98 out of 1008
# Unable to parse response time for listing id: 1623609
# Unable to parse membership date for listing id: 1623609
# Error in getting amenities for listing iD: 1623609
# Processing Listing 99 out of 1008
# Unable to parse response time for listing id: 4614763
# Unable to parse membership date for listing id: 4614763
# Error in getting amenities for listing iD: 4614763
# Processing Listing 100 out of 1008
# Unable to parse response time for listing id: 562311
# Unable to parse membership date for listing id: 562311
# Error in getting amenities for listing iD: 562311
# Processing Listing 101 out of 1008
# Unable to parse response time for listing id: 2412489
# Unable to parse membership date for listing id: 2412489
# Unable to parse stars listing id: 2412489
# Error in getting amenities for listing iD: 2412489
# Processing Listing 102 out of 1008
# Unable to parse response time for listing id: 209514
# Unable to parse membership date for listing id: 209514
# Error in getting amenities for listing iD: 209514
# Processing Listing 103 out of 1008
# Unable to parse response time for listing id: 1725853
# Unable to parse membership date for listing id: 1725853
# Error in getting amenities for listing iD: 1725853
# Processing Listing 104 out of 1008
# Unable to parse response time for listing id: 4720278
# Unable to parse membership date for listing id: 4720278
# Error in getting amenities for listing iD: 4720278
# Processing Listing 105 out of 1008
# Unable to parse response time for listing id: 2694526
# Unable to parse membership date for listing id: 2694526
# Error in getting amenities for listing iD: 2694526
# Processing Listing 106 out of 1008
# Unable to parse response time for listing id: 808660
# Unable to parse membership date for listing id: 808660
# Error in getting amenities for listing iD: 808660
# Processing Listing 107 out of 1008
# Unable to parse response time for listing id: 41055
# Unable to parse membership date for listing id: 41055
# Error in getting amenities for listing iD: 41055
# Processing Listing 108 out of 1008
# Unable to parse response time for listing id: 3774460
# Unable to parse membership date for listing id: 3774460
# Error in getting amenities for listing iD: 3774460
# Processing Listing 109 out of 1008
# Unable to parse response time for listing id: 8055625
# Unable to parse membership date for listing id: 8055625
# Unable to parse stars listing id: 8055625
# Error in getting amenities for listing iD: 8055625
# Processing Listing 110 out of 1008
# Unable to parse response time for listing id: 1827655
# Unable to parse membership date for listing id: 1827655
# Error in getting amenities for listing iD: 1827655
# Processing Listing 111 out of 1008
# Unable to parse response time for listing id: 5670027
# Unable to parse membership date for listing id: 5670027
# Error in getting amenities for listing iD: 5670027
# Processing Listing 112 out of 1008
# Unable to parse response time for listing id: 3230459
# Unable to parse membership date for listing id: 3230459
# Error in getting amenities for listing iD: 3230459
# Processing Listing 113 out of 1008
# Unable to parse response time for listing id: 2126868
# Unable to parse membership date for listing id: 2126868
# Error in getting amenities for listing iD: 2126868
# Processing Listing 114 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/2178509
# Error finding *About Listing* for listing ID: 2178509
# Error in getting Space Elements for listing iD: 2178509
# Processing Listing 115 out of 1008
# Unable to parse response time for listing id: 7973885
# Unable to parse membership date for listing id: 7973885
# Unable to parse stars listing id: 7973885
# Error in getting amenities for listing iD: 7973885
# Processing Listing 116 out of 1008
# Unable to parse response time for listing id: 3716504
# Unable to parse membership date for listing id: 3716504
# Error in getting amenities for listing iD: 3716504
# Processing Listing 117 out of 1008
# Unable to parse response time for listing id: 82919
# Unable to parse membership date for listing id: 82919
# Error in getting amenities for listing iD: 82919
# Processing Listing 118 out of 1008
# Unable to parse response time for listing id: 1336998
# Unable to parse membership date for listing id: 1336998
# Error in getting amenities for listing iD: 1336998
# Processing Listing 119 out of 1008
# Unable to parse response time for listing id: 256148
# Unable to parse membership date for listing id: 256148
# Error in getting amenities for listing iD: 256148
# Processing Listing 120 out of 1008
# Unable to parse response time for listing id: 348714
# Unable to parse membership date for listing id: 348714
# Error in getting amenities for listing iD: 348714
# Processing Listing 121 out of 1008
# Unable to parse response time for listing id: 3309928
# Unable to parse membership date for listing id: 3309928
# Error in getting amenities for listing iD: 3309928
# Processing Listing 122 out of 1008
# Unable to parse response time for listing id: 5287755
# Unable to parse membership date for listing id: 5287755
# Error in getting amenities for listing iD: 5287755
# Processing Listing 123 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/557423
# Error finding *About Listing* for listing ID: 557423
# Error in getting Space Elements for listing iD: 557423
# Processing Listing 124 out of 1008
# Unable to parse response time for listing id: 1408281
# Unable to parse membership date for listing id: 1408281
# Error in getting amenities for listing iD: 1408281
# Processing Listing 125 out of 1008
# Unable to parse response time for listing id: 1284122
# Unable to parse membership date for listing id: 1284122
# Error in getting amenities for listing iD: 1284122
# Processing Listing 126 out of 1008
# Unable to parse response time for listing id: 2515611
# Unable to parse membership date for listing id: 2515611
# Error in getting amenities for listing iD: 2515611
# Processing Listing 127 out of 1008
# Unable to parse response time for listing id: 2466755
# Unable to parse membership date for listing id: 2466755
# Error in getting amenities for listing iD: 2466755
# Processing Listing 128 out of 1008
# Unable to parse response time for listing id: 8172708
# Unable to parse membership date for listing id: 8172708
# Unable to parse stars listing id: 8172708
# Error in getting amenities for listing iD: 8172708
# Processing Listing 129 out of 1008
# Unable to parse response time for listing id: 1197716
# Unable to parse membership date for listing id: 1197716
# Error in getting amenities for listing iD: 1197716
# Processing Listing 130 out of 1008
# Unable to parse response time for listing id: 1193395
# Unable to parse membership date for listing id: 1193395
# Error in getting amenities for listing iD: 1193395
# Processing Listing 131 out of 1008
# Unable to parse response time for listing id: 8174659
# Unable to parse membership date for listing id: 8174659
# Unable to parse stars listing id: 8174659
# Error in getting amenities for listing iD: 8174659
# Processing Listing 132 out of 1008
# Unable to parse response time for listing id: 1226596
# Unable to parse membership date for listing id: 1226596
# Error in getting amenities for listing iD: 1226596
# Processing Listing 133 out of 1008
# Unable to parse response time for listing id: 394575
# Unable to parse membership date for listing id: 394575
# Error in getting amenities for listing iD: 394575
# Processing Listing 134 out of 1008
# Unable to parse response time for listing id: 1279292
# Unable to parse membership date for listing id: 1279292
# Error in getting amenities for listing iD: 1279292
# Processing Listing 135 out of 1008
# Unable to parse response time for listing id: 5193
# Unable to parse membership date for listing id: 5193
# Error in getting amenities for listing iD: 5193
# Processing Listing 136 out of 1008
# Unable to parse response time for listing id: 1478708
# Unable to parse membership date for listing id: 1478708
# Unable to parse stars listing id: 1478708
# Error in getting amenities for listing iD: 1478708
# Processing Listing 137 out of 1008
# Unable to parse response time for listing id: 25662
# Unable to parse membership date for listing id: 25662
# Error in getting amenities for listing iD: 25662
# Processing Listing 138 out of 1008
# Unable to parse response time for listing id: 4833101
# Unable to parse membership date for listing id: 4833101
# Error in getting amenities for listing iD: 4833101
# Processing Listing 139 out of 1008
# Unable to parse response time for listing id: 3676814
# Unable to parse membership date for listing id: 3676814
# Error in getting amenities for listing iD: 3676814
# Processing Listing 140 out of 1008
# Unable to parse response time for listing id: 746079
# Unable to parse membership date for listing id: 746079
# Error in getting amenities for listing iD: 746079
# Processing Listing 141 out of 1008
# Unable to parse response time for listing id: 7829055
# Unable to parse membership date for listing id: 7829055
# Error in getting amenities for listing iD: 7829055
# Processing Listing 142 out of 1008
# Unable to parse response time for listing id: 3082327
# Unable to parse membership date for listing id: 3082327
# Error in getting amenities for listing iD: 3082327
# Processing Listing 143 out of 1008
# Unable to parse response time for listing id: 5075470
# Unable to parse membership date for listing id: 5075470
# Error in getting amenities for listing iD: 5075470
# Processing Listing 144 out of 1008
# Unable to parse response time for listing id: 189894
# Unable to parse membership date for listing id: 189894
# Error in getting amenities for listing iD: 189894
# Processing Listing 145 out of 1008
# Unable to parse response time for listing id: 213532
# Unable to parse membership date for listing id: 213532
# Error in getting amenities for listing iD: 213532
# Processing Listing 146 out of 1008
# Unable to parse response time for listing id: 1198464
# Unable to parse membership date for listing id: 1198464
# Error in getting amenities for listing iD: 1198464
# Processing Listing 147 out of 1008
# Unable to parse response time for listing id: 1619632
# Unable to parse membership date for listing id: 1619632
# Error in getting amenities for listing iD: 1619632
# Processing Listing 148 out of 1008
# Unable to parse response time for listing id: 5253439
# Unable to parse membership date for listing id: 5253439
# Error in getting amenities for listing iD: 5253439
# Processing Listing 149 out of 1008
# Unable to parse response time for listing id: 4699861
# Unable to parse membership date for listing id: 4699861
# Unable to parse stars listing id: 4699861
# Error in getting amenities for listing iD: 4699861
# Processing Listing 150 out of 1008
# Unable to parse response time for listing id: 1150867
# Unable to parse membership date for listing id: 1150867
# Error in getting amenities for listing iD: 1150867
# Processing Listing 151 out of 1008
# Unable to parse response time for listing id: 5196399
# Unable to parse membership date for listing id: 5196399
# Error in getting amenities for listing iD: 5196399
# Processing Listing 152 out of 1008
# Unable to parse response time for listing id: 905399
# Unable to parse membership date for listing id: 905399
# Error in getting amenities for listing iD: 905399
# Processing Listing 153 out of 1008
# Unable to parse response time for listing id: 6389242
# Unable to parse membership date for listing id: 6389242
# Unable to parse stars listing id: 6389242
# Error in getting amenities for listing iD: 6389242
# Processing Listing 154 out of 1008
# Unable to parse response time for listing id: 41172
# Unable to parse membership date for listing id: 41172
# Error in getting amenities for listing iD: 41172
# Processing Listing 155 out of 1008
# Unable to parse response time for listing id: 7699095
# Unable to parse membership date for listing id: 7699095
# Unable to parse stars listing id: 7699095
# Error in getting amenities for listing iD: 7699095
# Processing Listing 156 out of 1008
# Unable to parse response time for listing id: 6390313
# Unable to parse membership date for listing id: 6390313
# Unable to parse stars listing id: 6390313
# Error in getting amenities for listing iD: 6390313
# Processing Listing 157 out of 1008
# Unable to parse response time for listing id: 6169292
# Unable to parse membership date for listing id: 6169292
# Unable to parse stars listing id: 6169292
# Error in getting amenities for listing iD: 6169292
# Processing Listing 158 out of 1008
# Unable to parse response time for listing id: 6629798
# Unable to parse membership date for listing id: 6629798
# Error in getting amenities for listing iD: 6629798
# Processing Listing 159 out of 1008
# Unable to parse response time for listing id: 909063
# Unable to parse membership date for listing id: 909063
# Error in getting amenities for listing iD: 909063
# Processing Listing 160 out of 1008
# Unable to parse response time for listing id: 7399265
# Unable to parse membership date for listing id: 7399265
# Unable to parse stars listing id: 7399265
# Error in getting amenities for listing iD: 7399265
# Processing Listing 161 out of 1008
# Unable to parse response time for listing id: 437385
# Unable to parse membership date for listing id: 437385
# Error in getting amenities for listing iD: 437385
# Processing Listing 162 out of 1008
# Unable to parse response time for listing id: 644948
# Unable to parse membership date for listing id: 644948
# Error in getting amenities for listing iD: 644948
# Processing Listing 163 out of 1008
# Unable to parse response time for listing id: 488297
# Unable to parse membership date for listing id: 488297
# Error in getting amenities for listing iD: 488297
# Processing Listing 164 out of 1008
# Unable to parse response time for listing id: 570318
# Unable to parse membership date for listing id: 570318
# Error in getting amenities for listing iD: 570318
# Processing Listing 165 out of 1008
# Unable to parse response time for listing id: 242004
# Unable to parse membership date for listing id: 242004
# Error in getting amenities for listing iD: 242004
# Processing Listing 166 out of 1008
# Unable to parse response time for listing id: 300589
# Unable to parse membership date for listing id: 300589
# Error in getting amenities for listing iD: 300589
# Processing Listing 167 out of 1008
# Unable to parse response time for listing id: 6688004
# Unable to parse membership date for listing id: 6688004
# Error in getting amenities for listing iD: 6688004
# Processing Listing 168 out of 1008
# Unable to parse response time for listing id: 1931925
# Unable to parse membership date for listing id: 1931925
# Error in getting amenities for listing iD: 1931925
# Processing Listing 169 out of 1008
# Unable to parse response time for listing id: 1759587
# Unable to parse membership date for listing id: 1759587
# Error in getting amenities for listing iD: 1759587
# Processing Listing 170 out of 1008
# Unable to parse response time for listing id: 8192732
# Unable to parse membership date for listing id: 8192732
# Unable to parse stars listing id: 8192732
# Error in getting amenities for listing iD: 8192732
# Processing Listing 171 out of 1008
# Unable to parse response time for listing id: 5415450
# Unable to parse membership date for listing id: 5415450
# Error in getting amenities for listing iD: 5415450
# Processing Listing 172 out of 1008
# Unable to parse response time for listing id: 137546
# Unable to parse membership date for listing id: 137546
# Error in getting amenities for listing iD: 137546
# Processing Listing 173 out of 1008
# Unable to parse response time for listing id: 1857709
# Unable to parse membership date for listing id: 1857709
# Error in getting amenities for listing iD: 1857709
# Processing Listing 174 out of 1008
# Unable to parse response time for listing id: 1998111
# Unable to parse membership date for listing id: 1998111
# Error in getting amenities for listing iD: 1998111
# Processing Listing 175 out of 1008
# Unable to parse response time for listing id: 7401158
# Unable to parse membership date for listing id: 7401158
# Error in getting amenities for listing iD: 7401158
# Processing Listing 176 out of 1008
# Unable to parse response time for listing id: 7085722
# Unable to parse membership date for listing id: 7085722
# Error in getting amenities for listing iD: 7085722
# Processing Listing 177 out of 1008
# Unable to parse response time for listing id: 4120646
# Unable to parse membership date for listing id: 4120646
# Error in getting amenities for listing iD: 4120646
# Processing Listing 178 out of 1008
# Unable to parse response time for listing id: 1717096
# Unable to parse membership date for listing id: 1717096
# Error in getting amenities for listing iD: 1717096
# Processing Listing 179 out of 1008
# Unable to parse response time for listing id: 7479448
# Unable to parse membership date for listing id: 7479448
# Unable to parse stars listing id: 7479448
# Error in getting amenities for listing iD: 7479448
# Processing Listing 180 out of 1008
# Unable to parse response time for listing id: 4040371
# Unable to parse membership date for listing id: 4040371
# Error in getting amenities for listing iD: 4040371
# Processing Listing 181 out of 1008
# Unable to parse response time for listing id: 2856542
# Unable to parse membership date for listing id: 2856542
# Error in getting amenities for listing iD: 2856542
# Processing Listing 182 out of 1008
# Unable to parse response time for listing id: 764010
# Unable to parse membership date for listing id: 764010
# Error in getting amenities for listing iD: 764010
# Processing Listing 183 out of 1008
# Unable to parse response time for listing id: 6852080
# Unable to parse membership date for listing id: 6852080
# Error in getting amenities for listing iD: 6852080
# Processing Listing 184 out of 1008
# Unable to parse response time for listing id: 728585
# Unable to parse membership date for listing id: 728585
# Error in getting amenities for listing iD: 728585
# Processing Listing 185 out of 1008
# Unable to parse response time for listing id: 6451436
# Unable to parse membership date for listing id: 6451436
# Error in getting amenities for listing iD: 6451436
# Processing Listing 186 out of 1008
# Unable to parse response time for listing id: 2123469
# Unable to parse membership date for listing id: 2123469
# Error in getting amenities for listing iD: 2123469
# Processing Listing 187 out of 1008
# Unable to parse response time for listing id: 87640
# Unable to parse membership date for listing id: 87640
# Error in getting amenities for listing iD: 87640
# Processing Listing 188 out of 1008
# Unable to parse response time for listing id: 220418
# Unable to parse membership date for listing id: 220418
# Error in getting amenities for listing iD: 220418
# Processing Listing 189 out of 1008
# Unable to parse response time for listing id: 4058557
# Unable to parse membership date for listing id: 4058557
# Error in getting amenities for listing iD: 4058557
# Processing Listing 190 out of 1008
# Unable to parse response time for listing id: 41867
# Unable to parse membership date for listing id: 41867
# Error in getting amenities for listing iD: 41867
# Processing Listing 191 out of 1008
# Unable to parse response time for listing id: 7019515
# Unable to parse membership date for listing id: 7019515
# Unable to parse stars listing id: 7019515
# Error in getting amenities for listing iD: 7019515
# Processing Listing 192 out of 1008
# Unable to parse response time for listing id: 516836
# Unable to parse membership date for listing id: 516836
# Error in getting amenities for listing iD: 516836
# Processing Listing 193 out of 1008
# Unable to parse response time for listing id: 5007358
# Unable to parse membership date for listing id: 5007358
# Error in getting amenities for listing iD: 5007358
# Processing Listing 194 out of 1008
# Unable to parse response time for listing id: 25463
# Unable to parse membership date for listing id: 25463
# Error in getting amenities for listing iD: 25463
# Processing Listing 195 out of 1008
# Unable to parse response time for listing id: 4720851
# Unable to parse membership date for listing id: 4720851
# Unable to parse stars listing id: 4720851
# Error in getting amenities for listing iD: 4720851
# Processing Listing 196 out of 1008
# Unable to parse response time for listing id: 24535
# Unable to parse membership date for listing id: 24535
# Error in getting amenities for listing iD: 24535
# Processing Listing 197 out of 1008
# Unable to parse response time for listing id: 2658295
# Unable to parse membership date for listing id: 2658295
# Error in getting amenities for listing iD: 2658295
# Processing Listing 198 out of 1008
# Unable to parse response time for listing id: 1678121
# Unable to parse membership date for listing id: 1678121
# Error in getting amenities for listing iD: 1678121
# Processing Listing 199 out of 1008
# Unable to parse response time for listing id: 5670010
# Unable to parse membership date for listing id: 5670010
# Error in getting amenities for listing iD: 5670010
# Processing Listing 200 out of 1008
# Unable to parse response time for listing id: 6079779
# Unable to parse membership date for listing id: 6079779
# Unable to parse stars listing id: 6079779
# Error in getting amenities for listing iD: 6079779
# Processing Listing 201 out of 1008
# Unable to parse response time for listing id: 258873
# Unable to parse membership date for listing id: 258873
# Error in getting amenities for listing iD: 258873
# Processing Listing 202 out of 1008
# Unable to parse response time for listing id: 678556
# Unable to parse membership date for listing id: 678556
# Error in getting amenities for listing iD: 678556
# Processing Listing 203 out of 1008
# Unable to parse response time for listing id: 1511076
# Unable to parse membership date for listing id: 1511076
# Error in getting amenities for listing iD: 1511076
# Processing Listing 204 out of 1008
# Unable to parse response time for listing id: 1255826
# Unable to parse membership date for listing id: 1255826
# Error in getting amenities for listing iD: 1255826
# Processing Listing 205 out of 1008
# Unable to parse response time for listing id: 1984709
# Unable to parse membership date for listing id: 1984709
# Error in getting amenities for listing iD: 1984709
# Processing Listing 206 out of 1008
# Unable to parse response time for listing id: 1412259
# Unable to parse membership date for listing id: 1412259
# Unable to parse stars listing id: 1412259
# Error in getting amenities for listing iD: 1412259
# Processing Listing 207 out of 1008
# Unable to parse response time for listing id: 4359078
# Unable to parse membership date for listing id: 4359078
# Error in getting amenities for listing iD: 4359078
# Processing Listing 208 out of 1008
# Unable to parse response time for listing id: 6107258
# Unable to parse membership date for listing id: 6107258
# Unable to parse stars listing id: 6107258
# Error in getting amenities for listing iD: 6107258
# Processing Listing 209 out of 1008
# Unable to parse response time for listing id: 955071
# Unable to parse membership date for listing id: 955071
# Error in getting amenities for listing iD: 955071
# Processing Listing 210 out of 1008
# Unable to parse response time for listing id: 1684346
# Unable to parse membership date for listing id: 1684346
# Error in getting amenities for listing iD: 1684346
# Processing Listing 211 out of 1008
# Unable to parse response time for listing id: 2042095
# Unable to parse membership date for listing id: 2042095
# Error in getting amenities for listing iD: 2042095
# Processing Listing 212 out of 1008
# Unable to parse response time for listing id: 548357
# Unable to parse membership date for listing id: 548357
# Error in getting amenities for listing iD: 548357
# Processing Listing 213 out of 1008
# Unable to parse response time for listing id: 7546927
# Unable to parse membership date for listing id: 7546927
# Unable to parse stars listing id: 7546927
# Error in getting amenities for listing iD: 7546927
# Processing Listing 214 out of 1008
# Unable to parse response time for listing id: 3842056
# Unable to parse membership date for listing id: 3842056
# Unable to parse stars listing id: 3842056
# Error in getting amenities for listing iD: 3842056
# Processing Listing 215 out of 1008
# Unable to parse response time for listing id: 1271318
# Unable to parse membership date for listing id: 1271318
# Error in getting amenities for listing iD: 1271318
# Processing Listing 216 out of 1008
# Unable to parse response time for listing id: 1056356
# Unable to parse membership date for listing id: 1056356
# Error in getting amenities for listing iD: 1056356
# Processing Listing 217 out of 1008
# Unable to parse response time for listing id: 1056844
# Unable to parse membership date for listing id: 1056844
# Error in getting amenities for listing iD: 1056844
# Processing Listing 218 out of 1008
# Unable to parse response time for listing id: 6628985
# Unable to parse membership date for listing id: 6628985
# Error in getting amenities for listing iD: 6628985
# Processing Listing 219 out of 1008
# Unable to parse response time for listing id: 4718531
# Unable to parse membership date for listing id: 4718531
# Error in getting amenities for listing iD: 4718531
# Processing Listing 220 out of 1008
# Unable to parse response time for listing id: 6645606
# Unable to parse membership date for listing id: 6645606
# Error in getting amenities for listing iD: 6645606
# Processing Listing 221 out of 1008
# Unable to parse response time for listing id: 8153250
# Unable to parse membership date for listing id: 8153250
# Unable to parse stars listing id: 8153250
# Error in getting amenities for listing iD: 8153250
# Processing Listing 222 out of 1008
# Unable to parse response time for listing id: 3615430
# Unable to parse membership date for listing id: 3615430
# Unable to parse stars listing id: 3615430
# Error in getting amenities for listing iD: 3615430
# Processing Listing 223 out of 1008
# Unable to parse response time for listing id: 3832296
# Unable to parse membership date for listing id: 3832296
# Error in getting amenities for listing iD: 3832296
# Processing Listing 224 out of 1008
# Unable to parse response time for listing id: 7955727
# Unable to parse membership date for listing id: 7955727
# Error in getting amenities for listing iD: 7955727
# Processing Listing 225 out of 1008
# Unable to parse response time for listing id: 7437151
# Unable to parse membership date for listing id: 7437151
# Unable to parse stars listing id: 7437151
# Error in getting amenities for listing iD: 7437151
# Processing Listing 226 out of 1008
# Unable to parse response time for listing id: 6092596
# Unable to parse membership date for listing id: 6092596
# Error in getting amenities for listing iD: 6092596
# Processing Listing 227 out of 1008
# Unable to parse response time for listing id: 568161
# Unable to parse membership date for listing id: 568161
# Error in getting amenities for listing iD: 568161
# Processing Listing 228 out of 1008
# Unable to parse response time for listing id: 212125
# Unable to parse membership date for listing id: 212125
# Error in getting amenities for listing iD: 212125
# Processing Listing 229 out of 1008
# Unable to parse response time for listing id: 277339
# Unable to parse membership date for listing id: 277339
# Error in getting amenities for listing iD: 277339
# Processing Listing 230 out of 1008
# Unable to parse response time for listing id: 8118808
# Unable to parse membership date for listing id: 8118808
# Unable to parse stars listing id: 8118808
# Error in getting amenities for listing iD: 8118808
# Processing Listing 231 out of 1008
# Unable to parse response time for listing id: 6437264
# Unable to parse membership date for listing id: 6437264
# Error in getting amenities for listing iD: 6437264
# Processing Listing 232 out of 1008
# Unable to parse response time for listing id: 896938
# Unable to parse membership date for listing id: 896938
# Error in getting amenities for listing iD: 896938
# Processing Listing 233 out of 1008
# Unable to parse response time for listing id: 1678077
# Unable to parse membership date for listing id: 1678077
# Error in getting amenities for listing iD: 1678077
# Processing Listing 234 out of 1008
# Unable to parse response time for listing id: 960593
# Unable to parse membership date for listing id: 960593
# Error in getting amenities for listing iD: 960593
# Processing Listing 235 out of 1008
# Unable to parse response time for listing id: 4885932
# Unable to parse membership date for listing id: 4885932
# Error in getting amenities for listing iD: 4885932
# Processing Listing 236 out of 1008
# Unable to parse response time for listing id: 752762
# Unable to parse membership date for listing id: 752762
# Error in getting amenities for listing iD: 752762
# Processing Listing 237 out of 1008
# Unable to parse response time for listing id: 7513438
# Unable to parse membership date for listing id: 7513438
# Error in getting amenities for listing iD: 7513438
# Processing Listing 238 out of 1008
# Unable to parse response time for listing id: 611132
# Unable to parse membership date for listing id: 611132
# Error in getting amenities for listing iD: 611132
# Processing Listing 239 out of 1008
# Unable to parse response time for listing id: 6364873
# ...
# Error in getting amenities for listing iD: 4765557
# Processing Listing 933 out of 1008
# Unable to parse response time for listing id: 7548762
# Unable to parse membership date for listing id: 7548762
# Unable to parse stars listing id: 7548762
# Error in getting amenities for listing iD: 7548762
# Processing Listing 934 out of 1008
# Unable to parse response time for listing id: 594387
# Unable to parse membership date for listing id: 594387
# Error in getting amenities for listing iD: 594387
# Processing Listing 935 out of 1008
# Unable to parse response time for listing id: 6888361
# Unable to parse membership date for listing id: 6888361
# Error in getting amenities for listing iD: 6888361
# Processing Listing 936 out of 1008
# Unable to parse response time for listing id: 7278506
# Unable to parse membership date for listing id: 7278506
# Error in getting amenities for listing iD: 7278506
# Processing Listing 937 out of 1008
# Unable to parse response time for listing id: 13705
# Unable to parse membership date for listing id: 13705
# Error in getting amenities for listing iD: 13705
# Processing Listing 938 out of 1008
# Unable to parse response time for listing id: 5496658
# Unable to parse membership date for listing id: 5496658
# Unable to parse stars listing id: 5496658
# Error in getting amenities for listing iD: 5496658
# Processing Listing 939 out of 1008
# Unable to parse response time for listing id: 7853803
# Unable to parse membership date for listing id: 7853803
# Unable to parse stars listing id: 7853803
# Error in getting amenities for listing iD: 7853803
# Processing Listing 940 out of 1008
# Unable to parse response time for listing id: 2056543
# Unable to parse membership date for listing id: 2056543
# Error in getting amenities for listing iD: 2056543
# Processing Listing 941 out of 1008
# Unable to parse response time for listing id: 4198073
# Unable to parse membership date for listing id: 4198073
# Error in getting amenities for listing iD: 4198073
# Processing Listing 942 out of 1008
# Unable to parse response time for listing id: 4925354
# Unable to parse membership date for listing id: 4925354
# Error in getting amenities for listing iD: 4925354
# Processing Listing 943 out of 1008
# Unable to parse response time for listing id: 7133178
# Unable to parse membership date for listing id: 7133178
# Unable to parse stars listing id: 7133178
# Error in getting amenities for listing iD: 7133178
# Processing Listing 944 out of 1008
# Unable to parse response time for listing id: 442632
# Unable to parse membership date for listing id: 442632
# Error in getting amenities for listing iD: 442632
# Processing Listing 945 out of 1008
# Unable to parse response time for listing id: 3116974
# Unable to parse membership date for listing id: 3116974
# Error in getting amenities for listing iD: 3116974
# Processing Listing 946 out of 1008
# Unable to parse response time for listing id: 734871
# Unable to parse membership date for listing id: 734871
# Unable to parse stars listing id: 734871
# Error in getting amenities for listing iD: 734871
# Processing Listing 947 out of 1008
# Unable to parse response time for listing id: 1336450
# Unable to parse membership date for listing id: 1336450
# Error in getting amenities for listing iD: 1336450
# Processing Listing 948 out of 1008
# Unable to parse response time for listing id: 6187679
# Unable to parse membership date for listing id: 6187679
# Unable to parse stars listing id: 6187679
# Error in getting amenities for listing iD: 6187679
# Processing Listing 949 out of 1008
# Unable to parse response time for listing id: 7728613
# Unable to parse membership date for listing id: 7728613
# Unable to parse stars listing id: 7728613
# Error in getting amenities for listing iD: 7728613
# Processing Listing 950 out of 1008
# Unable to parse response time for listing id: 7935826
# Unable to parse membership date for listing id: 7935826
# Unable to parse stars listing id: 7935826
# Error in getting amenities for listing iD: 7935826
# Processing Listing 951 out of 1008
# Unable to parse response time for listing id: 6586433
# Unable to parse membership date for listing id: 6586433
# Error in getting amenities for listing iD: 6586433
# Processing Listing 952 out of 1008
# Unable to parse response time for listing id: 2007569
# Unable to parse membership date for listing id: 2007569
# Error in getting amenities for listing iD: 2007569
# Processing Listing 953 out of 1008
# Unable to parse response time for listing id: 4170452
# Unable to parse membership date for listing id: 4170452
# Unable to parse stars listing id: 4170452
# Error in getting amenities for listing iD: 4170452
# Processing Listing 954 out of 1008
# Unable to parse response time for listing id: 6560870
# Unable to parse membership date for listing id: 6560870
# Error in getting amenities for listing iD: 6560870
# Processing Listing 955 out of 1008
# Unable to parse response time for listing id: 330736
# Unable to parse membership date for listing id: 330736
# Error in getting amenities for listing iD: 330736
# Processing Listing 956 out of 1008
# Unable to parse response time for listing id: 7806968
# Unable to parse membership date for listing id: 7806968
# Unable to parse stars listing id: 7806968
# Error in getting amenities for listing iD: 7806968
# Processing Listing 957 out of 1008
# Unable to parse response time for listing id: 7953240
# Unable to parse membership date for listing id: 7953240
# Unable to parse stars listing id: 7953240
# Error in getting amenities for listing iD: 7953240
# Processing Listing 958 out of 1008
# Unable to parse response time for listing id: 1855096
# Unable to parse membership date for listing id: 1855096
# Error in getting amenities for listing iD: 1855096
# Processing Listing 959 out of 1008
# Unable to parse response time for listing id: 3656251
# Unable to parse membership date for listing id: 3656251
# Error in getting amenities for listing iD: 3656251
# Processing Listing 960 out of 1008
# Unable to parse response time for listing id: 1421774
# Unable to parse membership date for listing id: 1421774
# Error in getting amenities for listing iD: 1421774
# Processing Listing 961 out of 1008
# Unable to parse response time for listing id: 1438864
# Unable to parse membership date for listing id: 1438864
# Error in getting amenities for listing iD: 1438864
# Processing Listing 962 out of 1008
# Unable to parse response time for listing id: 1931459
# Unable to parse membership date for listing id: 1931459
# Error in getting amenities for listing iD: 1931459
# Processing Listing 963 out of 1008
# Unable to parse response time for listing id: 741178
# Unable to parse membership date for listing id: 741178
# Error in getting amenities for listing iD: 741178
# Processing Listing 964 out of 1008
# Unable to parse response time for listing id: 1130826
# Unable to parse membership date for listing id: 1130826
# Error in getting amenities for listing iD: 1130826
# Processing Listing 965 out of 1008
# Unable to parse response time for listing id: 3759368
# Unable to parse membership date for listing id: 3759368
# Error in getting amenities for listing iD: 3759368
# Processing Listing 966 out of 1008
# Unable to parse response time for listing id: 5536512
# Unable to parse membership date for listing id: 5536512
# Error in getting amenities for listing iD: 5536512
# Processing Listing 967 out of 1008
# Unable to parse response time for listing id: 2096909
# Unable to parse membership date for listing id: 2096909
# Error in getting amenities for listing iD: 2096909
# Processing Listing 968 out of 1008
# Unable to parse response time for listing id: 4803418
# Unable to parse membership date for listing id: 4803418
# Error in getting amenities for listing iD: 4803418
# Processing Listing 969 out of 1008
# Unable to parse response time for listing id: 1487398
# Unable to parse membership date for listing id: 1487398
# Error in getting amenities for listing iD: 1487398
# Processing Listing 970 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/7204241
# Error finding *About Listing* for listing ID: 7204241
# Error in getting Space Elements for listing iD: 7204241
# Processing Listing 971 out of 1008
# Unable to parse response time for listing id: 4263551
# Unable to parse membership date for listing id: 4263551
# Error in getting amenities for listing iD: 4263551
# Processing Listing 972 out of 1008
# Unable to parse response time for listing id: 8085920
# Unable to parse membership date for listing id: 8085920
# Unable to parse stars listing id: 8085920
# Error in getting amenities for listing iD: 8085920
# Processing Listing 973 out of 1008
# Unable to parse response time for listing id: 2701658
# Unable to parse membership date for listing id: 2701658
# Error in getting amenities for listing iD: 2701658
# Processing Listing 974 out of 1008
# Unable to parse response time for listing id: 7927795
# Unable to parse membership date for listing id: 7927795
# Unable to parse stars listing id: 7927795
# Error in getting amenities for listing iD: 7927795
# Processing Listing 975 out of 1008
# Unable to parse response time for listing id: 5551468
# Unable to parse membership date for listing id: 5551468
# Error in getting amenities for listing iD: 5551468
# Processing Listing 976 out of 1008
# Unable to parse response time for listing id: 1022316
# Unable to parse membership date for listing id: 1022316
# Error in getting amenities for listing iD: 1022316
# Processing Listing 977 out of 1008
# Unable to parse response time for listing id: 4850420
# Unable to parse membership date for listing id: 4850420
# Unable to parse stars listing id: 4850420
# Error in getting amenities for listing iD: 4850420
# Processing Listing 978 out of 1008
# Unable to parse response time for listing id: 2197345
# Unable to parse membership date for listing id: 2197345
# Error in getting amenities for listing iD: 2197345
# Processing Listing 979 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/5196859
# Error finding *About Listing* for listing ID: 5196859
# Error in getting Space Elements for listing iD: 5196859
# Processing Listing 980 out of 1008
# Unable to parse response time for listing id: 7602645
# Unable to parse membership date for listing id: 7602645
# Error in getting amenities for listing iD: 7602645
# Processing Listing 981 out of 1008
# Unable to parse response time for listing id: 4745604
# Unable to parse membership date for listing id: 4745604
# Error in getting amenities for listing iD: 4745604
# Processing Listing 982 out of 1008
# Unable to parse response time for listing id: 7665146
# Unable to parse membership date for listing id: 7665146
# Unable to parse stars listing id: 7665146
# Error in getting amenities for listing iD: 7665146
# Processing Listing 983 out of 1008
# Unable to parse response time for listing id: 1847664
# Unable to parse membership date for listing id: 1847664
# Error in getting amenities for listing iD: 1847664
# Processing Listing 984 out of 1008
# Unable to parse response time for listing id: 6994279
# Unable to parse membership date for listing id: 6994279
# Unable to parse stars listing id: 6994279
# Error in getting amenities for listing iD: 6994279
# Processing Listing 985 out of 1008
# Unable to parse response time for listing id: 2020393
# Unable to parse membership date for listing id: 2020393
# Error in getting amenities for listing iD: 2020393
# Processing Listing 986 out of 1008
# Unable to parse response time for listing id: 6246035
# Unable to parse membership date for listing id: 6246035
# Error in getting amenities for listing iD: 6246035
# Processing Listing 987 out of 1008
# Unable to parse response time for listing id: 7734510
# Unable to parse membership date for listing id: 7734510
# Unable to parse stars listing id: 7734510
# Error in getting amenities for listing iD: 7734510
# Processing Listing 988 out of 1008
# Unable to parse response time for listing id: 229319
# Unable to parse membership date for listing id: 229319
# Error in getting amenities for listing iD: 229319
# Processing Listing 989 out of 1008
# Unable to parse response time for listing id: 2372569
# Unable to parse membership date for listing id: 2372569
# Error in getting amenities for listing iD: 2372569
# Processing Listing 990 out of 1008
# Unable to parse response time for listing id: 4387948
# Unable to parse membership date for listing id: 4387948
# Unable to parse stars listing id: 4387948
# Error in getting amenities for listing iD: 4387948
# Processing Listing 991 out of 1008
# Was not able to fetch data from https://www.airbnb.com/rooms/1407881
# Error finding *About Listing* for listing ID: 1407881
# Error in getting Space Elements for listing iD: 1407881
# Processing Listing 992 out of 1008
# Unable to parse response time for listing id: 2123241
# Unable to parse membership date for listing id: 2123241
# Error in getting amenities for listing iD: 2123241
# Processing Listing 993 out of 1008
# Unable to parse response time for listing id: 4603953
# Unable to parse membership date for listing id: 4603953
# Error in getting amenities for listing iD: 4603953
# Processing Listing 994 out of 1008
# Unable to parse response time for listing id: 1344306
# Unable to parse membership date for listing id: 1344306
# Error in getting amenities for listing iD: 1344306
# Processing Listing 995 out of 1008
# Unable to parse response time for listing id: 7886398
# Unable to parse membership date for listing id: 7886398
# Unable to parse stars listing id: 7886398
# Error in getting amenities for listing iD: 7886398
# Processing Listing 996 out of 1008
# Unable to parse response time for listing id: 7775182
# Unable to parse membership date for listing id: 7775182
# Unable to parse stars listing id: 7775182
# Error in getting amenities for listing iD: 7775182
# Processing Listing 997 out of 1008
# Unable to parse response time for listing id: 6808807
# Unable to parse membership date for listing id: 6808807
# Unable to parse stars listing id: 6808807
# Error in getting amenities for listing iD: 6808807
# Processing Listing 998 out of 1008
# Unable to parse response time for listing id: 4431152
# Unable to parse membership date for listing id: 4431152
# Unable to parse stars listing id: 4431152
# Error in getting amenities for listing iD: 4431152
# Processing Listing 999 out of 1008
# Unable to parse response time for listing id: 3727061
# Unable to parse membership date for listing id: 3727061
# Error in getting amenities for listing iD: 3727061
# Processing Listing 1000 out of 1008
# Unable to parse response time for listing id: 4038823
# Unable to parse membership date for listing id: 4038823
# Error in getting amenities for listing iD: 4038823
# Processing Listing 1001 out of 1008
# Unable to parse response time for listing id: 7674061
# Unable to parse membership date for listing id: 7674061
# Unable to parse stars listing id: 7674061
# Error in getting amenities for listing iD: 7674061
# Processing Listing 1002 out of 1008
# Unable to parse response time for listing id: 714955
# Unable to parse membership date for listing id: 714955
# Error in getting amenities for listing iD: 714955
# Processing Listing 1003 out of 1008
# Unable to parse response time for listing id: 786268
# Unable to parse membership date for listing id: 786268
# Error in getting amenities for listing iD: 786268
# Processing Listing 1004 out of 1008
# Unable to parse response time for listing id: 1489501
# Unable to parse membership date for listing id: 1489501
# Error in getting amenities for listing iD: 1489501
# Processing Listing 1005 out of 1008
# Unable to parse response time for listing id: 2995611
# Unable to parse membership date for listing id: 2995611
# Unable to parse stars listing id: 2995611
# Error in getting amenities for listing iD: 2995611
# Processing Listing 1006 out of 1008
# Unable to parse response time for listing id: 859336
# Unable to parse membership date for listing id: 859336
# Error in getting amenities for listing iD: 859336
# Processing Listing 1007 out of 1008
# Unable to parse response time for listing id: 4558542
# Unable to parse membership date for listing id: 4558542
# Error in getting amenities for listing iD: 4558542
# Processing Listing 1008 out of 1008
# Unable to parse response time for listing id: 7181461
# Unable to parse membership date for listing id: 7181461
# Error in getting amenities for listing iD: 7181461

# %%
 writeToCSV(MainResults, 'Airbnb.csv')

# %%
 writeToCSV(DetailResults, 'Airbnb.csv')
